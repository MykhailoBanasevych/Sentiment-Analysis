# %% [markdown]
# ### Import libraries

# %%
import pandas as pd 
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalizer

# %% [markdown]
# ### Read opinions from CSV file

# %%
opinions = pd.read_csv('./merged.csv', encoding="UTF-8")

# %%
opinions = opinions[['opinion', 'score', 'sentiment']]

# %%
opinions.sentiment = opinions.sentiment.apply(lambda o: sa.polarity_scores(o))

# %%
opinions.vader = SentimentIntensityAnalizer()
opinions.vader = (opinions.opinion)
